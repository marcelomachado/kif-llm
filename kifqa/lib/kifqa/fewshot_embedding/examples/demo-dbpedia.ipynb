# %%
# %pip install tqdm

# %pip install ipywidgets
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from kifqa.fewshot_embedding.embedding_serializer import EmbeddingSerializer
from kifqa.fewshot_embedding.loaders import JsonlLoader, CsvLoader
from kifqa.model.example import Example
# from .autonotebook import tqdm as notebook_tqdm

# %%
from typing import Optional


def parser(entry: str) -> Optional[Example]:
    try:
        input = str(entry['question'])
        output_str = ''
        output = []
        for triple in entry['triples']:
            if len(triple) == 3:
                output.append(f"""
    {{
        "subject": "{triple[0]}",
        "property": "{triple[1]}",
        "object": "{triple[2]}"
    }}""")
            inner = ',\n'.join(output)
            output_str = f"""
[
{inner}
]"""
        return Example(input, output_str)
    except Exception as e:
        print(f'could not parse entry {entry}, exception={e}')

output_path='/Users/marcelomachado/Documents/projects/kifqa/data-curated/annotated_db_data_train.pkl'

# %%
serializer = EmbeddingSerializer(loader=JsonlLoader())
serializer.save_to_pickle(
    input_path='/Users/marcelomachado/Documents/projects/kifqa/data-curated2/db_data_train_with_draft_triple.jsonl',
    output_path=output_path,
    parser_fn=parser)
# Out:
# /Users/marcelomachado/Documents/projects/kifqa/venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
import pickle
with open(output_path, 'rb') as f:
    entries = pickle.load(f)

print(entries[:3])
# Out:
# [{'input': 'what movie is produced by warner bros', 'output': '\n[\n\n    {\n        "subject": "?x",\n        "property": "distributor",\n        "object": "Warner Bros."\n    }\n]', 'embedding': array([-5.91885410e-02, -8.46093372e-02, -5.85781559e-02,  2.44096257e-02,
#         5.08783991e-03,  2.06292253e-02, -6.89378455e-02, -4.65585031e-02,
#         7.96978101e-02, -6.36450872e-02,  1.21384840e-02,  5.65342754e-02,
#        -7.26475660e-03,  5.22969477e-02,  2.16793418e-02,  3.17075150e-03,
#         2.88073961e-02, -4.59777527e-02,  4.21800790e-03, -1.03431001e-01,
#         1.84578467e-02, -1.98765621e-02,  1.28182769e-02,  2.64899572e-03,
#        -9.45782848e-03, -6.49214759e-02,  2.67218854e-02,  3.22063863e-02,
#        -1.34795513e-02, -1.03713730e-02,  1.28310779e-02,  4.66739014e-02,
#        -7.22754374e-02, -6.03100881e-02,  4.46040891e-02, -5.72572136e-03,
#        -1.72115732e-02, -2.32024677e-02,  1.31080514e-02, -6.07894436e-02,
# ...
